# %% [markdown]
# <a href="https://colab.research.google.com/github/donkalakamakshiharshitha/ML-DL/blob/master/python_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr=np.array([[101,'ajay',20,'chennai'],[102,'harshitha',40,'hyderabad'],[103,'rajitha',60,'banglore']])
print(arr)
# Out:
# [['101' 'ajay' '20' 'chennai']
#  ['102' 'harshitha' '40' 'hyderabad']
#  ['103' 'rajitha' '60' 'banglore']]

# %%
import pandas as pd
df=pd.DataFrame(arr,columns=['ID','name','age','city'])
df
# Out:
#     ID       name age       city
# 0  101       ajay  20    chennai
# 1  102  harshitha  40  hyderabad
# 2  103    rajitha  60   banglore

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.columns
# Out:
# Index(['ID', 'name', 'age', 'city'], dtype='object')

# %%
df['name'][0]="dinesh"
df
# Out:
#     ID       name age       city
# 0  101     dinesh  20    chennai
# 1  102  harshitha  40  hyderabad
# 2  103    rajitha  60   banglore

# %%
df['name']
df
# Out:
#     ID       name age       city
# 0  101     dinesh  20    chennai
# 1  102  harshitha  40  hyderabad
# 2  103    rajitha  60   banglore

# %%
df=df.assign(income=[1000,1500,2000])
df
# Out:
#     ID       name age       city  income
# 0  101     dinesh  20    chennai    1000
# 1  102  harshitha  40  hyderabad    1500
# 2  103    rajitha  60   banglore    2000

# %%
df.set_index("ID")
# Out:
#           name age       city  income
# ID
# 101     dinesh  20    chennai    1000
# 102  harshitha  40  hyderabad    1500
# 103    rajitha  60   banglore    2000

# %%
df=df.assign(bonus=[200,120,500])
df
# Out:
#     ID       name age       city  income  bonus
# 0  101     dinesh  20    chennai    1000    200
# 1  102  harshitha  40  hyderabad    1500    120
# 2  103    rajitha  60   banglore    2000    500

# %%
del df['bonus']
df
# Out:
#     ID       name age       city  income
# 0  101     dinesh  20    chennai    1000
# 1  102  harshitha  40  hyderabad    1500
# 2  103    rajitha  60   banglore    2000
